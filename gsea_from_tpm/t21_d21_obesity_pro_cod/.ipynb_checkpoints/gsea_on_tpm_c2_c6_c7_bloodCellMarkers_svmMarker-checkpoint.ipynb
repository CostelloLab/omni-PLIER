# %%
import time
import os

start_seconds = time.time()

project_root_path=os.path.abspath(os.path.join(os.path.dirname('__file__'),'..','..'))

#wd_sn_costello_lab/project/htp_da/ml_dl_pipelines/logistic_elastic_net/PSB2025/gsea_from_tpm/d21_t21_pro_cod/
project_root_path=os.path.join(project_root_path,'gsea_from_tpm','t21_d21_obesity_pro_cod')

print(project_root_path)
# Out:
# /media/sutanu/wd_sn_costello_lab/project/omni_PLIER/gsea_from_tpm/t21_d21_obesity_pro_cod

# %%
#----------Read HTP Transcriptomic dataset for T21 patients in disease co-occurrence conditions -------------------- 
import pandas as pd
master_htp_tpm_w_ds_co_occu = pd.read_csv(os.path.join(project_root_path,"input","master_htp_tpm_t21_d21_w_ds_co_occu.csv"), sep=",")
master_htp_tpm_w_ds_co_occu.index=master_htp_tpm_w_ds_co_occu['LabID']

#pro_HTP_WholeBlood_RNAseq_FPKMs_T21.index=pro_HTP_WholeBlood_RNAseq_FPKMs_T21['LabID']

master_htp_tpm_w_ds_co_occu.head(2)
# Out:
#              RecordID   Sex Karyotype Event_name     LabID  Age_at_visit  \
# LabID
# HTP0591A  INVAB226VEU  Male       T21    Visit 1  HTP0591A          31.9
# HTP0330A  INVAC526BJC  Male       T21    Visit 1  HTP0330A           6.1
#
#                 BMI Sample_source  Anxiety  Any autoimmune skin condition  \
# LabID
# HTP0591A  30.816524      NDSC2019      NaN                            NaN
# HTP0330A  16.307117         Local      0.0                            1.0
#
#           ...  ENSG00000122952.17  ENSG00000198205.6  ENSG00000198455.4  \
# LabID     ...
# HTP0591A  ...            1.935566           3.937682          10.845141
# HTP0330A  ...            1.672534           8.833969          18.819949
#
#           ENSG00000070476.15  ENSG00000203995.10  ENSG00000232242.2  \
# LabID
# HTP0591A           16.656438            0.099931                0.0
# HTP0330A           23.307585            0.063715                0.0
#
# ...

# %%
master_htp_tpm_t21_obesity=master_htp_tpm_w_ds_co_occu[((master_htp_tpm_w_ds_co_occu['Karyotype']=='T21')|(master_htp_tpm_w_ds_co_occu['Karyotype']=='Control'))&((master_htp_tpm_w_ds_co_occu['Obesity']==1.0)|(master_htp_tpm_w_ds_co_occu['Obesity']==0.0))]

# %%
master_htp_tpm_t21_obesity.iloc[:,1:25]
# Out:
#               Sex Karyotype Event_name      LabID  Age_at_visit        BMI  \
# LabID
# HTP0591A     Male       T21    Visit 1   HTP0591A          31.9  30.816524
# HTP0330A     Male       T21    Visit 1   HTP0330A           6.1  16.307117
# HTP0052A2  Female       T21    Visit 2  HTP0052A2          29.9  28.136703
# HTP0236A2    Male       T21    Visit 2  HTP0236A2          11.3  14.800472
# HTP0491A     Male       T21    Visit 1   HTP0491A           6.5  18.142091
# ...           ...       ...        ...        ...           ...        ...
# HTP0468A2    Male       T21    Visit 2  HTP0468A2          29.7  29.257302
# HTP0585A   Female       T21    Visit 1   HTP0585A          16.5  23.854017
# HTP0437A     Male       T21    Visit 1   HTP0437A          24.9  27.262769
# HTP0207A4  Female       T21    Visit 4  HTP0207A4          25.2  21.264113
# HTP0384A   Female       T21    Visit 1   HTP0384A          27.8  38.130981
#
# ...

# %%
htp_tpm_t21_obesity=master_htp_tpm_t21_obesity.copy()

# %%
htp_tpm_t21_obesity.head(2)
# Out:
#              RecordID   Sex Karyotype Event_name     LabID  Age_at_visit  \
# LabID
# HTP0591A  INVAB226VEU  Male       T21    Visit 1  HTP0591A          31.9
# HTP0330A  INVAC526BJC  Male       T21    Visit 1  HTP0330A           6.1
#
#                 BMI Sample_source  Anxiety  Any autoimmune skin condition  \
# LabID
# HTP0591A  30.816524      NDSC2019      NaN                            NaN
# HTP0330A  16.307117         Local      0.0                            1.0
#
#           ...  ENSG00000122952.17  ENSG00000198205.6  ENSG00000198455.4  \
# LabID     ...
# HTP0591A  ...            1.935566           3.937682          10.845141
# HTP0330A  ...            1.672534           8.833969          18.819949
#
#           ENSG00000070476.15  ENSG00000203995.10  ENSG00000232242.2  \
# LabID
# HTP0591A           16.656438            0.099931                0.0
# HTP0330A           23.307585            0.063715                0.0
#
# ...

# %%
##----------Protein Coding gene information ---------------------------------------------------------------------

temp_HTP_WholeBlood_RNAseq_FPKMs = pd.read_csv(os.path.join(project_root_path,"input","HTP_WholeBlood_RNAseq_FPKMs_Synapse.txt"), sep="\t")

#temp_HTP_WholeBlood_RNAseq_FPKMs.head(2)
protein_coding_genes_w_chr21=(temp_HTP_WholeBlood_RNAseq_FPKMs['EnsemblID'][(temp_HTP_WholeBlood_RNAseq_FPKMs['Gene_type'] == 'protein_coding')].unique())

# %%
len(protein_coding_genes_w_chr21)
# Out:
# 19957

# %%
#---------Dataframe TPM for protein coding gene only with chr21 -------------------------------------------------

htp_tpm_pro_cod_t21_obesity= htp_tpm_t21_obesity[protein_coding_genes_w_chr21]
htp_tpm_pro_cod_t21_obesity.head(2)

#
# Out:
#           ENSG00000121410.12  ENSG00000148584.15  ENSG00000175899.14  \
# LabID
# HTP0591A            0.280640                 0.0            0.276813
# HTP0330A            0.876778                 0.0            0.341377
#
#           ENSG00000166535.20  ENSG00000184389.9  ENSG00000128274.17  \
# LabID
# HTP0591A            0.010946           0.336842            0.156064
# HTP0330A            0.000000           1.315452            0.212831
#
#           ENSG00000118017.4  ENSG00000094914.14  ENSG00000081760.17  \
# LabID
# HTP0591A           0.193698            4.870604            2.419529
# HTP0330A           0.000000            5.097316            3.743754
#
#           ENSG00000114771.14  ...  ENSG00000086827.9  ENSG00000174442.12  \
# LabID                         ...
# HTP0591A                 0.0  ...          10.708767            2.278396
# HTP0330A                 0.0  ...          11.593791            3.700548
#
# ...

# %%
from sklearn.feature_selection import VarianceThreshold

#-------------Filter FPKMs Dataframe based on Varinace Threshold ----------------


threshold_n=0.01
#sel = VarianceThreshold(threshold=(threshold_n* (1 - threshold_n) ))
sel = VarianceThreshold(threshold= threshold_n)
sel_var=sel.fit_transform(htp_tpm_pro_cod_t21_obesity)
htp_tpm_pro_cod_t21_obesity_avt=htp_tpm_pro_cod_t21_obesity[htp_tpm_pro_cod_t21_obesity.columns[sel.get_support(indices=True)]].copy()

# %%
htp_tpm_pro_cod_t21_obesity_avt.head(2)
# Out:
#           ENSG00000121410.12  ENSG00000175899.14  ENSG00000184389.9  \
# LabID
# HTP0591A            0.280640            0.276813           0.336842
# HTP0330A            0.876778            0.341377           1.315452
#
#           ENSG00000128274.17  ENSG00000094914.14  ENSG00000081760.17  \
# LabID
# HTP0591A            0.156064            4.870604            2.419529
# HTP0330A            0.212831            5.097316            3.743754
#
#           ENSG00000103591.13  ENSG00000115977.19  ENSG00000087884.14  \
# LabID
# HTP0591A            20.19250           10.139333            2.755297
# HTP0330A            26.42234           17.475143            2.058951
#
#           ENSG00000127837.9  ...  ENSG00000153975.10  ENSG00000086827.9  \
# LabID                        ...
# HTP0591A          38.188341  ...            5.325755          10.708767
# HTP0330A          33.267594  ...           14.007106          11.593791
#
# ...

# %%
htp_tpm_t21_obesity.head(2)
# Out:
#              RecordID   Sex Karyotype Event_name     LabID  Age_at_visit  \
# LabID
# HTP0591A  INVAB226VEU  Male       T21    Visit 1  HTP0591A          31.9
# HTP0330A  INVAC526BJC  Male       T21    Visit 1  HTP0330A           6.1
#
#                 BMI Sample_source  Anxiety  Any autoimmune skin condition  \
# LabID
# HTP0591A  30.816524      NDSC2019      NaN                            NaN
# HTP0330A  16.307117         Local      0.0                            1.0
#
#           ...  ENSG00000122952.17  ENSG00000198205.6  ENSG00000198455.4  \
# LabID     ...
# HTP0591A  ...            1.935566           3.937682          10.845141
# HTP0330A  ...            1.672534           8.833969          18.819949
#
#           ENSG00000070476.15  ENSG00000203995.10  ENSG00000232242.2  \
# LabID
# HTP0591A           16.656438            0.099931                0.0
# HTP0330A           23.307585            0.063715                0.0
#
# ...

# %%
htp_tpm_pro_cod_t21_obesity_avt.head(2)
# Out:
#           ENSG00000121410.12  ENSG00000175899.14  ENSG00000184389.9  \
# LabID
# HTP0591A            0.280640            0.276813           0.336842
# HTP0330A            0.876778            0.341377           1.315452
#
#           ENSG00000128274.17  ENSG00000094914.14  ENSG00000081760.17  \
# LabID
# HTP0591A            0.156064            4.870604            2.419529
# HTP0330A            0.212831            5.097316            3.743754
#
#           ENSG00000103591.13  ENSG00000115977.19  ENSG00000087884.14  \
# LabID
# HTP0591A            20.19250           10.139333            2.755297
# HTP0330A            26.42234           17.475143            2.058951
#
#           ENSG00000127837.9  ...  ENSG00000153975.10  ENSG00000086827.9  \
# LabID                        ...
# HTP0591A          38.188341  ...            5.325755          10.708767
# HTP0330A          33.267594  ...           14.007106          11.593791
#
# ...

# %%
from combat.pycombat import pycombat #Batch correction

#-------Batch correction based on sample source (pycombat method)-----------------------

df_temp1_tpm_pro_cod_t21_d21_avt= pd.DataFrame(htp_tpm_t21_obesity['Sample_source']).merge(htp_tpm_pro_cod_t21_obesity_avt, left_index=True, right_index=True, how='inner')

#df_tpm_htp_tpm_pro_cod_t21_obesity_avt = pycombat(htp_tpm_pro_cod_t21_obesity_avt.drop(columns=["group_Sample_source_age_sex"]).transpose(), htp_tpm_pro_cod_t21_obesity_avt["group_Sample_source_age_sex"], mean_only=True).transpose()

#df_tpm_htp_tpm_pro_cod_t21_obesity_avt.head(2)

# %%
df_tpm_htp_tpm_pro_cod_t21_obesity_avt_bc = pycombat(df_temp1_tpm_pro_cod_t21_d21_avt.drop(columns=["Sample_source"]).transpose(), df_temp1_tpm_pro_cod_t21_d21_avt["Sample_source"], mean_only=True).transpose()
df_tpm_htp_tpm_pro_cod_t21_obesity_avt_bc.head(2)
# Out:
# Using mean only version
# Found 3 batches.
# Adjusting for 0 covariate(s) or covariate level(s).
# Standardizing Data across genes.
# Fitting L/S model and finding priors.
# Finding parametric adjustments.
# Adjusting the Data
#           ENSG00000121410.12  ENSG00000175899.14  ENSG00000184389.9  \
# LabID
# HTP0591A            0.325073            0.306704           0.732781
# HTP0330A            0.821739            0.303450           0.823688
#
#           ENSG00000128274.17  ENSG00000094914.14  ENSG00000081760.17  \
# LabID
# HTP0591A            0.225536            5.047003            2.568829
# HTP0330A            0.124731            4.866466            3.549809
#
#           ENSG00000103591.13  ENSG00000115977.19  ENSG00000087884.14  \
# LabID
# HTP0591A           21.179381           11.213489            2.895877
# HTP0330A           25.232325           16.121105            1.891504
#
#           ENSG00000127837.9  ...  ENSG00000153975.10  ENSG00000086827.9  \
# ...

# %%
df_tpm_htp_tpm_pro_cod_t21_obesity_avt_bc.head(2)
# Out:
#           ENSG00000121410.12  ENSG00000175899.14  ENSG00000184389.9  \
# LabID
# HTP0591A            0.325073            0.306704           0.732781
# HTP0330A            0.821739            0.303450           0.823688
#
#           ENSG00000128274.17  ENSG00000094914.14  ENSG00000081760.17  \
# LabID
# HTP0591A            0.225536            5.047003            2.568829
# HTP0330A            0.124731            4.866466            3.549809
#
#           ENSG00000103591.13  ENSG00000115977.19  ENSG00000087884.14  \
# LabID
# HTP0591A           21.179381           11.213489            2.895877
# HTP0330A           25.232325           16.121105            1.891504
#
#           ENSG00000127837.9  ...  ENSG00000153975.10  ENSG00000086827.9  \
# LabID                        ...
# HTP0591A          39.262072  ...            6.332801          11.285727
# HTP0330A          31.806116  ...           12.819025          10.859128
#
# ...

# %%
df_tpm_htp_tpm_pro_cod_t21_obesity_avt_bc.shape

htp_tpm_pro_cod_t21_obesity=df_tpm_htp_tpm_pro_cod_t21_obesity_avt_bc

# %%
tran_htp_tpm_pro_cod_t21_obesity=htp_tpm_pro_cod_t21_obesity.transpose()
tran_htp_tpm_pro_cod_t21_obesity['ensemble_id']=tran_htp_tpm_pro_cod_t21_obesity.index

# %%
display(tran_htp_tpm_pro_cod_t21_obesity.head(2))
# Out:
# LabID               HTP0591A  HTP0330A  HTP0052A2  HTP0236A2  HTP0491A  \
# ENSG00000121410.12  0.325073  0.821739   0.508732   0.435258  0.469703
# ENSG00000175899.14  0.306704  0.303450   0.150221   0.165537  0.292113
#
# LabID               HTP0599A  HTP0464A  HTP0544A  HTP0541A  HTP0467A  ...  \
# ENSG00000121410.12  0.155875  0.283255  0.209346  0.274977  0.375145  ...
# ENSG00000175899.14  0.290235  0.121949  0.338098  0.181797  0.128585  ...
#
# LabID               HTP0548A  HTP0609A  HTP0333A2  HTP0537A  HTP0468A2  \
# ENSG00000121410.12  0.274122  1.264982   0.519869  0.406006   0.357034
# ENSG00000175899.14  0.338832  0.090557   0.290376  0.163261   0.385665
#
# LabID               HTP0585A  HTP0437A  HTP0207A4  HTP0384A  \
# ENSG00000121410.12  0.308977  0.453074   0.740682  0.228033
# ENSG00000175899.14  0.201559  0.103486   0.121408  0.146367
#
# LabID                      ensemble_id
# ENSG00000121410.12  ENSG00000121410.12
# ENSG00000175899.14  ENSG00000175899.14
#
# ...

# %%
import pandas as pd
genecode_v33_ensemble_id_gene_name=pd.read_csv("./input/genecode_v33_ensemble_id_gene_name.csv")

display(genecode_v33_ensemble_id_gene_name.head(2))
# Out:
#          ensemble_id gene_name
# 0  ENSG00000223972.5   DDX11L1
# 1  ENSG00000227232.5    WASH7P

# %%
tran_htp_tpm_pro_cod_t21_obesity_remp1=genecode_v33_ensemble_id_gene_name.merge(tran_htp_tpm_pro_cod_t21_obesity, on=['ensemble_id'], how='inner')

# %%
tran_htp_tpm_pro_cod_t21_obesity_remp1=tran_htp_tpm_pro_cod_t21_obesity_remp1.rename(columns={'gene_name':'Gene'})

tran_htp_tpm_pro_cod_t21_obesity_remp1[['ensemble_id','Gene']]=tran_htp_tpm_pro_cod_t21_obesity_remp1[['Gene','ensemble_id']]

tran_htp_tpm_pro_cod_t21_obesity_remp1=tran_htp_tpm_pro_cod_t21_obesity_remp1.rename(columns={'ensemble_id':'Gene1'})
tran_htp_tpm_pro_cod_t21_obesity_remp1=tran_htp_tpm_pro_cod_t21_obesity_remp1.rename(columns={'Gene':'ensemble_id'})
tran_htp_tpm_pro_cod_t21_obesity_remp1=tran_htp_tpm_pro_cod_t21_obesity_remp1.rename(columns={'Gene1':'Gene'})

tran_htp_tpm_pro_cod_t21_obesity_remp1.head(2)
# Out:
#      Gene         ensemble_id   HTP0591A   HTP0330A  HTP0052A2  HTP0236A2  \
# 0   NOC2L  ENSG00000188976.11  35.276086  31.857552  30.418291  34.876934
# 1  KLHL17  ENSG00000187961.14  13.067254  13.862052  15.899807  14.124698
#
#     HTP0491A   HTP0599A   HTP0464A   HTP0544A  ...   HTP0630A   HTP0548A  \
# 0  32.128974  31.063553  30.517542  38.200050  ...  37.018946  33.835749
# 1  17.134403  11.406983  11.937480   8.943379  ...  15.256782  10.936466
#
#     HTP0609A  HTP0333A2   HTP0537A  HTP0468A2   HTP0585A   HTP0437A  \
# 0  35.001742  21.648935  34.100001  44.570899  27.383965  31.849290
# 1  19.578480  11.223749  12.259418  12.228479   8.081418  12.478539
#
#    HTP0207A4   HTP0384A
# 0  30.543183  26.563358
# 1  15.806375   7.495007
#
# [2 rows x 364 columns]

# %%
htp_tpm_t21_obesity[['LabID','Obesity']]
# Out:
#                LabID  Obesity
# LabID
# HTP0591A    HTP0591A      1.0
# HTP0330A    HTP0330A      0.0
# HTP0052A2  HTP0052A2      0.0
# HTP0236A2  HTP0236A2      0.0
# HTP0491A    HTP0491A      0.0
# ...              ...      ...
# HTP0468A2  HTP0468A2      0.0
# HTP0585A    HTP0585A      0.0
# HTP0437A    HTP0437A      0.0
# HTP0207A4  HTP0207A4      0.0
# HTP0384A    HTP0384A      1.0
#
# [362 rows x 2 columns]

# %%
class_label=(htp_tpm_t21_obesity[['Obesity']].transpose())

# %%
class_vector=list(class_label.iloc[0])

# %%
import gseapy as gp
from gseapy import Msigdb
msig = Msigdb()
# mouse hallmark gene sets
#gmt = msig.get_gmt(category='c2.all', dbver="2023.2.Hs")
#gmt='/sutanu/media/wd_sn_costello_lab/project/htp_da/reverse_eng_PLIER_to_MSigDB/input/data/unzip/msigdb_v4.0_files_to_download_locally/msigdb_v4.0_GMTs/c2.all.v4.0.symbols.gmt'
gmt='./input/msigdb_v_4_C2_c6_c7_bloodCellMarkersIRISDMAP_svmMarkers.gmt'
gsea_plot="./output/htp_tpm_gsea_c2_c6_c7_bloodCellMarkersIRISDMAP_svmMarkers_all_pro_cod_t21_obesity.jpeg"
# run gsea
# enrichr libraries are supported by gsea module. Just provide the name
gs_res = gp.gsea(data=tran_htp_tpm_pro_cod_t21_obesity_remp1, # or data='./P53_resampling_data.txt'
                 gene_sets=gmt, # or enrichr library names
                 cls= class_vector, # cls=class_vector
                 # set permutation_type to phenotype if samples >=15
                 threads=25,
                 min_size=5,
                 max_size=500,
                 permutation_num=100000, # reduce number to speed up testing
                 outdir=None, # don't write to disk
                 method='signal_to_noise',
                 seed=6,
                 verbose=True, # see what's going on behind the scenes
                )
gs_res.pheno_pos = "Obesity +Ve"
gs_res.pheno_neg = "Obesity -Ve"


terms = gs_res.res2d.Term
axs = gs_res.plot(terms=terms[1])


axs.savefig(gsea_plot, bbox_inches = 'tight')


gs_res.res2d.to_csv("./output/htp_tpm_gsea_c2_c6_c7_bloodCellMarkersIRISDMAP_svmMarkers_all_pro_cod_t21_obesity.csv")


gsea_ranking=gs_res.ranking
genes_w_ranking=pd.DataFrame(gsea_ranking)
genes_w_ranking['gene_name']=genes_w_ranking.index
genes_w_ranking=genes_w_ranking.rename(columns={0:'Ranks'})


genes_w_ranking.to_csv("./output/rank_htp_tpm_gsea_c2_c6_c7_bloodCellMarkersIRISDMAP_svmMarkers_all_pro_cod_t21_obesity.csv")

display(gs_res.res2d.head(10))
display(gs_res.res2d.tail(10))
# Out:
# /home/snandi/anaconda3/envs/htp_da/lib/python3.11/site-packages/gseapy/msigdb.py:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   d = pd.read_html(resp.text)[0]
# /home/snandi/anaconda3/envs/htp_da/lib/python3.11/site-packages/gseapy/msigdb.py:72: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   d = pd.read_html(resp.text)[0]
# 2024-07-30 06:17:00,607 [INFO] Parsing data files for GSEA.............................
# 2024-07-30 06:17:00,639 [WARNING] Found duplicated gene names, values averaged by gene names!
# /home/snandi/anaconda3/envs/htp_da/lib/python3.11/site-packages/gseapy/gsea.py:105: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
# ...

# %%
gs_res.res2d
# Out:
#       Name                                         Term        ES       NES  \
# 0     gsea   GSE34205_HEALTHY_VS_RSV_INF_INFANT_PBMC_DN   0.73763  2.053057
# 1     gsea         BOYAULT_LIVER_CANCER_SUBCLASS_G23_DN  -0.78042 -1.912182
# 2     gsea       GSE34205_RSV_VS_FLU_INF_INFANT_PBMC_UP  0.687824   1.87153
# 3     gsea                  MCBRYAN_TERMINAL_END_BUD_UP  0.834666  1.860278
# 4     gsea                                    DMAP_ERY5  0.633762  1.828893
# ...    ...                                          ...       ...       ...
# 6657  gsea          CHNG_MULTIPLE_MYELOMA_HYPERPLOID_UP  0.121435  0.286037
# 6658  gsea               KANG_DOXORUBICIN_RESISTANCE_UP -0.105608 -0.248204
# 6659  gsea       SOTIRIOU_BREAST_CANCER_GRADE_1_VS_3_UP -0.092072 -0.241198
# 6660  gsea  ROSTY_CERVICAL_CANCER_PROLIFERATION_CLUSTER -0.091827  -0.24113
# 6661  gsea      GSE15750_DAY6_VS_DAY10_EFF_CD8_TCELL_UP -0.073167 -0.218242
#
#      NOM p-val FDR q-val FWER p-val    Tag %  Gene %  \
# ...

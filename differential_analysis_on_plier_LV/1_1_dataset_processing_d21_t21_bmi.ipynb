# %%
#----------Read HTP Transcriptomic dataset for T21 patients in disease co-occurrence conditions -------------------- 
import pandas as pd
master_htp_tpm_w_ds_co_occu = pd.read_csv("./input/master_htp_tpm_w_ds_co_occu.csv", sep=",")
master_htp_tpm_w_ds_co_occu.index=master_htp_tpm_w_ds_co_occu['LabID']

#pro_HTP_WholeBlood_RNAseq_FPKMs_T21.index=pro_HTP_WholeBlood_RNAseq_FPKMs_T21['LabID']

master_htp_tpm_w_ds_co_occu.head(2)
# Out:
#               RecordID     Sex Karyotype Event_name      LabID  Age_at_visit  \
# LabID
# HTP0001B2  INVNP966YZK  Female   Control    Visit 3  HTP0001B2          25.8
# HTP0005A3  INVEX372AVT    Male       T21    Visit 3  HTP0005A3          36.5
#
#                  BMI Sample_source  Anxiety  Any autoimmune skin condition  \
# LabID
# HTP0001B2  21.929589         Local      1.0                            0.0
# HTP0005A3  24.346517         Local      1.0                            0.0
#
#            ...  ENSG00000122952.17  ENSG00000198205.6  ENSG00000198455.4  \
# LabID      ...
# HTP0001B2  ...            0.947527           8.018540          20.517068
# HTP0005A3  ...            0.978595           6.036048          14.630115
#
#            ENSG00000070476.15  ENSG00000203995.10  ENSG00000232242.2  \
# LabID
# HTP0001B2           29.897105            0.018589                0.0
# HTP0005A3           19.403144            0.082281                0.0
#
# ...

# %%
meta_data_htp=master_htp_tpm_w_ds_co_occu.iloc[:,range(1,25)].copy()

# %%
meta_data_htp.head(2)
# Out:
#               Sex Karyotype Event_name      LabID  Age_at_visit        BMI  \
# LabID
# HTP0001B2  Female   Control    Visit 3  HTP0001B2          25.8  21.929589
# HTP0005A3    Male       T21    Visit 3  HTP0005A3          36.5  24.346517
#
#           Sample_source  Anxiety  Any autoimmune skin condition  \
# LabID
# HTP0001B2         Local      1.0                            0.0
# HTP0005A3         Local      1.0                            0.0
#
#            Any congenital heart defect  ...  Asthma/reactive airway disease  \
# LabID                                   ...
# HTP0001B2                          0.0  ...                             0.0
# HTP0005A3                          0.0  ...                             0.0
#
#            Autism spectrum disorder  Cataracts  Celiac disease  Depression  \
# LabID
# HTP0001B2                       0.0        0.0             0.0         0.0
# HTP0005A3                       0.0        0.0             0.0         0.0
#
# ...

# %%
def f(row):
    if row['BMI'] >=30:
        val = 'BMI_GT_30'
    elif row['BMI'] <30:
        val = 'BMI_LT_30'
       
    return val
meta_data_htp = meta_data_htp[meta_data_htp['BMI'].notna()]
meta_data_htp['BMI_dis'] = meta_data_htp.apply(f, axis=1)
display(meta_data_htp.head(2))

print(meta_data_htp.shape)

meta_data_htp.to_csv("./output/HTP_meta_data_D21_T21_BMI.csv", index=False)
# Out:
#               Sex Karyotype Event_name      LabID  Age_at_visit        BMI  \
# LabID
# HTP0001B2  Female   Control    Visit 3  HTP0001B2          25.8  21.929589
# HTP0005A3    Male       T21    Visit 3  HTP0005A3          36.5  24.346517
#
#           Sample_source  Anxiety  Any autoimmune skin condition  \
# LabID
# HTP0001B2         Local      1.0                            0.0
# HTP0005A3         Local      1.0                            0.0
#
#            Any congenital heart defect  ...  Autism spectrum disorder  \
# LabID                                   ...
# HTP0001B2                          0.0  ...                       0.0
# HTP0005A3                          0.0  ...                       0.0
#
#            Cataracts  Celiac disease  Depression  \
# LabID
# HTP0001B2        0.0             0.0         0.0
# HTP0005A3        0.0             0.0         0.0
#
#            Frequent/Recurrent pneumonia  Obesity  Pulmonary hypertension  \
# LabID
# ...

# %%
import pandas as pd

df_htp_plier_model_k0_75_frac1=pd.read_csv("./input/htp_plier_model_k0.75_frac1.csv")



df_htp_plier_model_k0_75_frac1.index=df_htp_plier_model_k0_75_frac1['Unnamed: 0']

df_htp_plier_model_k0_75_frac1=df_htp_plier_model_k0_75_frac1.loc[meta_data_htp.index,]

df_htp_plier_model_k0_75_frac1.head(2)
# Out:
#           Unnamed: 0  1,REACTOME_PEPTIDE_CHAIN_ELONGATION  \
# LabID
# HTP0001B2  HTP0001B2                             0.821871
# HTP0005A3  HTP0005A3                             3.565815
#
#            2,BRACHAT_RESPONSE_TO_METHOTREXATE_DN  \
# LabID
# HTP0001B2                               8.314215
# HTP0005A3                              13.402728
#
#            3,TIEN_INTESTINE_PROBIOTICS_2HR_UP  \
# LabID
# HTP0001B2                           35.746765
# HTP0005A3                           27.449584
#
#            4,CAVARD_LIVER_CANCER_MALIGNANT_VS_BENIGN  \
# LabID
# HTP0001B2                                  -3.871701
# HTP0005A3                                  -1.540747
#
#            5,xCell:Erythrocytes_FANTOM_3  6,DAZARD_UV_RESPONSE_CLUSTER_G3  \
# LabID
# HTP0001B2                       7.172328                        -2.145759
# HTP0005A3                       8.521962                         5.472490
#
# ...

# %%
df_htp_plier_model_k0_75_frac1=df_htp_plier_model_k0_75_frac1.drop(['Unnamed: 0'], axis=1)

#df_htp_plier_model_k0_75_frac1=df_htp_plier_model_k0_75_frac1.abs()


#df_htp_plier_model_k0_75_frac1=df_htp_plier_model_k0_75_frac1.apply(pd.to_numeric)



tran_df_htp_plier_model_k0_75_frac1 = df_htp_plier_model_k0_75_frac1.transpose()
tran_df_htp_plier_model_k0_75_frac1['LVs_long']=tran_df_htp_plier_model_k0_75_frac1.index

tran_df_htp_plier_model_k0_75_frac1[['LVs','LVs_name']] = tran_df_htp_plier_model_k0_75_frac1['LVs_long'].str.split(',',expand=True)

tran_df_htp_plier_model_k0_75_frac1['LVs'] = 'LV' + tran_df_htp_plier_model_k0_75_frac1['LVs'].astype(str)


tran_df_htp_plier_model_k0_75_frac1=tran_df_htp_plier_model_k0_75_frac1.drop(['LVs_long','LVs_name'], axis=1)


display(df_htp_plier_model_k0_75_frac1.head(10))

tran_df_htp_plier_model_k0_75_frac1.to_csv('./output/plier_LVS_D21_T2_BMI_htp_for_deseq2.csv', index=False)
# Out:
#            1,REACTOME_PEPTIDE_CHAIN_ELONGATION  \
# LabID
# HTP0001B2                             0.821871
# HTP0005A3                             3.565815
# HTP0012A2                             3.218840
# HTP0015A4                            -0.179945
# HTP0017A4                             3.277688
# HTP0022B2                             4.324411
# HTP0023A2                             3.288493
# HTP0025A3                            -1.740912
# HTP0034B3                            -1.075468
# HTP0035B3                            -0.320005
#
#            2,BRACHAT_RESPONSE_TO_METHOTREXATE_DN  \
# LabID
# HTP0001B2                               8.314215
# HTP0005A3                              13.402728
# HTP0012A2                              13.662735
# HTP0015A4                              10.178655
# HTP0017A4                              24.533134
# HTP0022B2                              16.235195
# HTP0023A2                              21.667246
# ...
